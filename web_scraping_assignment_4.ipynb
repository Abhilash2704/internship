# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import regex as re
import time
from selenium.webdriver.common.alert import Alert
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome()
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
video_name = []
vid_nam = driver.find_elements(By.TAG_NAME,'td')
for i in vid_nam:
    try:
        video_name.append(i.text)
    except NoSuchElementException:
        video_name.append(' - ')

video_name
# Out:
# ['',
#  "hide\nThis section has multiple issues. Please help improve it or discuss these issues on the talk page. (Learn how and when to remove these template messages)\nThis section's factual accuracy is disputed. (February 2024)\nThis section needs expansion with: Information to the reader the auto-generated playlist from YouTube is not an index of a video popularity due to the views-counting algorithm. You can help by adding to it. (February 2024)",
#  '',
#  "This section's factual accuracy is disputed. (February 2024)",
#  '',
#  'This section needs expansion with: Information to the reader the auto-generated playlist from YouTube is not an index of a video popularity due to the views-counting algorithm. You can help by adding to it. (February 2024)',
#  '"Baby Shark Dance"[6]',
#  "Pinkfong Baby Shark - Kids' Songs & Stories",
#  '14.09',
#  'June 17, 2016',
#  '[A]',
#  '"Despacito"[9]',
#  'Luis Fonsi',
#  '8.38',
#  'January 12, 2017',
#  '[B]',
# ...

# %%
data = video_name[6:125]
data
# Out:
# ['"Baby Shark Dance"[6]',
#  "Pinkfong Baby Shark - Kids' Songs & Stories",
#  '14.09',
#  'June 17, 2016',
#  '[A]',
#  '"Despacito"[9]',
#  'Luis Fonsi',
#  '8.38',
#  'January 12, 2017',
#  '[B]',
#  '"Johny Johny Yes Papa"[17]',
#  "LooLoo Kids - Nursery Rhymes and Children's Songs",
#  '6.87',
#  'October 8, 2016',
#  '',
#  '"Bath Song"[18]',
#  'Cocomelon - Nursery Rhymes',
#  '6.62',
#  'May 2, 2018',
#  '',
#  '"Shape of You"[19]',
#  'Ed Sheeran',
#  '6.20',
#  'January 30, 2017',
#  '[C]',
#  '"See You Again"[22]',
#  'Wiz Khalifa',
#  '6.17',
#  'April 6, 2015',
#  '[D]',
#  '"Wheels on the Bus"[27]',
#  'Cocomelon - Nursery Rhymes',
#  '5.88',
#  'May 24, 2018',
#  '',
#  '"Phonics Song with Two Words"[28]',
#  'ChuChu TV Nursery Rhymes & Kids Songs',
#  '5.70',
#  'March 6, 2014',
#  '',
#  '"Uptown Funk"[29]',
#  'Mark Ronson',
#  '5.15',
#  'November 19, 2014',
#  '',
#  '"Learning Colors – Colorful Eggs on a Farm"[30]',
#  'Miroshka TV',
#  '5.07',
# ...

# %%
vid_name = data[0::5]
vid_name
# Out:
# ['"Baby Shark Dance"[6]',
#  '"Despacito"[9]',
#  '"Johny Johny Yes Papa"[17]',
#  '"Bath Song"[18]',
#  '"Shape of You"[19]',
#  '"See You Again"[22]',
#  '"Wheels on the Bus"[27]',
#  '"Phonics Song with Two Words"[28]',
#  '"Uptown Funk"[29]',
#  '"Learning Colors – Colorful Eggs on a Farm"[30]',
#  '"Gangnam Style"[31]',
#  '"Masha and the Bear – Recipe for Disaster"[36]',
#  '"Dame Tu Cosita"[37]',
#  '"Axel F"[38]',
#  '"Sugar"[39]',
#  '"Counting Stars"[40]',
#  '"Baa Baa Black Sheep"[41]',
#  '"Roar"[42]',
#  '"Lakdi Ki Kathi"[43]',
#  '"Waka Waka (This Time for Africa)"[44]',
#  '"Sorry"[45]',
#  '"Thinking Out Loud"[46]',
#  '"Humpty the train on a fruits ride"[47]',
#  '"Shree Hanuman Chalisa"[48]']

# %%
artist = data[1::5]
artist
# Out:
# ["Pinkfong Baby Shark - Kids' Songs & Stories",
#  'Luis Fonsi',
#  "LooLoo Kids - Nursery Rhymes and Children's Songs",
#  'Cocomelon - Nursery Rhymes',
#  'Ed Sheeran',
#  'Wiz Khalifa',
#  'Cocomelon - Nursery Rhymes',
#  'ChuChu TV Nursery Rhymes & Kids Songs',
#  'Mark Ronson',
#  'Miroshka TV',
#  'Psy',
#  'Get Movies',
#  'Ultra Records',
#  'Crazy Frog',
#  'Maroon 5',
#  'OneRepublic',
#  'Cocomelon - Nursery Rhymes',
#  'Katy Perry',
#  'Jingle Toons',
#  'Shakira',
#  'Justin Bieber',
#  'Ed Sheeran',
#  'Kiddiestv Hindi - Nursery Rhymes & Kids Songs',
#  'T-Series Bhakti Sagar']

# %%
views = data[2::5]
views
# Out:
# ['14.09',
#  '8.38',
#  '6.87',
#  '6.62',
#  '6.20',
#  '6.17',
#  '5.88',
#  '5.70',
#  '5.15',
#  '5.07',
#  '5.05',
#  '4.58',
#  '4.55',
#  '4.34',
#  '4.00',
#  '3.97',
#  '3.96',
#  '3.96',
#  '3.91',
#  '3.85',
#  '3.77',
#  '3.73',
#  '3.73',
#  '3.69']

# %%
upload_date =  data[3::5]
upload_date
# Out:
# ['June 17, 2016',
#  'January 12, 2017',
#  'October 8, 2016',
#  'May 2, 2018',
#  'January 30, 2017',
#  'April 6, 2015',
#  'May 24, 2018',
#  'March 6, 2014',
#  'November 19, 2014',
#  'February 27, 2018',
#  'July 15, 2012',
#  'January 31, 2012',
#  'April 5, 2018',
#  'June 16, 2009',
#  'January 14, 2015',
#  'May 31, 2013',
#  'June 25, 2018',
#  'September 5, 2013',
#  'June 14, 2018',
#  'June 4, 2010',
#  'October 22, 2015',
#  'October 7, 2014',
#  'January 26, 2018',
#  'May 10, 2011']

# %%
df = pd.DataFrame({'Video Name':vid_name,'Artist':artist,'Views in Billion':views,'Upload Date':upload_date})
df
# Out:
#                                          Video Name  \
# 0                             "Baby Shark Dance"[6]
# 1                                    "Despacito"[9]
# 2                        "Johny Johny Yes Papa"[17]
# 3                                   "Bath Song"[18]
# 4                                "Shape of You"[19]
# 5                               "See You Again"[22]
# 6                           "Wheels on the Bus"[27]
# 7                 "Phonics Song with Two Words"[28]
# 8                                 "Uptown Funk"[29]
# 9   "Learning Colors – Colorful Eggs on a Farm"[30]
# 10                              "Gangnam Style"[31]
# 11   "Masha and the Bear – Recipe for Disaster"[36]
# 12                             "Dame Tu Cosita"[37]
# 13                                     "Axel F"[38]
# 14                                      "Sugar"[39]
# 15                             "Counting Stars"[40]
# 16                        "Baa Baa Black Sheep"[41]
# ...

# %%
driver = webdriver.Chrome()
driver.get('https://www.bcci.tv/')

# %%
fixtures = driver.find_element(By.XPATH,'/html/body/header/div[3]/div[2]/ul/div[1]/a[2]')
fixtures.click()

# %%
series = []
place = []
date = []
time = []
data_info = driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
place_info = driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]')
date_info = driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')
time_info = driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
for i in data_info:
    try:
        series.append(i.text)
    except NoSuchElementException:
        series.append(' - ')
for i in place_info:
    try:
        place.append(i.text)
    except NoSuchElementException:
        place.append(' - ')
for i in date_info:
    try:
        date.append(i.text)
    except NoSuchElementException:
        date.append(' - ')
for i in time_info:
    try:
        time.append(i.text)
    except NoSuchElementException:
        time.append(' - ')
series = series[1:]
place = place[1:]
date = date[1:]
time = time[1:]

# %%
df = pd.DataFrame({'Series':series,'Place':place,'Date':date,'Time':time})
df
# Out:
#                         Series                Place           Date  \
# 0  INDIA TOUR OF ZIMBABWE 2024  Harare Sports Club,   6 JULY, 2024
# 1  INDIA TOUR OF ZIMBABWE 2024  Harare Sports Club,   7 JULY, 2024
# 2  INDIA TOUR OF ZIMBABWE 2024  Harare Sports Club,  10 JULY, 2024
# 3  INDIA TOUR OF ZIMBABWE 2024  Harare Sports Club,  13 JULY, 2024
# 4  INDIA TOUR OF ZIMBABWE 2024  Harare Sports Club,  14 JULY, 2024
#
#           Time
# 0  8:00 PM IST
# 1  8:00 PM IST
# 2  8:00 PM IST
# 3  8:00 PM IST
# 4  8:00 PM IST

# %%
driver = webdriver.Chrome()
driver.get('https://www.statisticstimes.com/')

# %%
drop_down = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/button')
drop_down.click()
country = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
country.click()
driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()

# %%
data = []
info = driver.find_elements(By.TAG_NAME,'td')
for i in info:
    data.append(i.text)
data
# Out:
# ['Source',
#  'Ministry of Statistics and Programme Implementation (17)',
#  'Date',
#  '21 Dec 2023',
#  '1',
#  'Maharashtra',
#  '-',
#  '3,108,022',
#  '13.24%',
#  '417.163',
#  '-',
#  '2,027,971',
#  '2',
#  'Tamil Nadu',
#  '2,364,514',
#  '2,071,286',
#  '8.82%',
#  '278.011',
#  '1,453,321',
#  '1,343,287',
#  '3',
#  'Uttar Pradesh',
#  '2,257,575',
#  '1,974,532',
#  '8.41%',
#  '265.024',
#  '1,304,678',
#  '1,204,660',
#  '4',
#  'Karnataka',
#  '2,241,368',
#  '1,962,725',
#  '8.36%',
#  '263.440',
#  '1,326,319',
#  '1,229,713',
#  '5',
#  'Gujarat',
#  '-',
#  '1,937,066',
#  '8.25%',
#  '259.996',
#  '-',
#  '1,372,204',
#  '6',
#  'West Bengal',
#  '1,554,992',
#  '1,363,926',
#  '5.81%',
#  '183.068',
#  '854,023',
#  '787,758',
#  '7',
#  'Rajasthan',
#  '1,413,620',
#  '1,218,193',
#  '5.19%',
#  '163.507',
#  '799,449',
#  '738,922',
#  '8',
#  'Madhya Pradesh',
#  '1,322,821',
#  '1,136,137',
#  '4.84%',
#  '152.494',
#  '643,124',
#  '600,689',
#  '9',
# ...

# %%
rank = data[4::8]
state = data[5::8]
gsdp22 = data[6::8]
gsdp21 = data[7::8]
share = data[8::8]
gdp = data[9::8]

# %%
df = pd.DataFrame({'Rank':rank[:33],'State':state[:33],'GSDP 22-23':gsdp22[:33],'GSDP':gsdp21[:33],'Share':share[:33],'GDP':gdp[:33]})
df
# Out:
#    Rank                      State GSDP 22-23       GSDP   Share      GDP
# 0     1                Maharashtra          -  3,108,022  13.24%  417.163
# 1     2                 Tamil Nadu  2,364,514  2,071,286   8.82%  278.011
# 2     3              Uttar Pradesh  2,257,575  1,974,532   8.41%  265.024
# 3     4                  Karnataka  2,241,368  1,962,725   8.36%  263.440
# 4     5                    Gujarat          -  1,937,066   8.25%  259.996
# 5     6                West Bengal  1,554,992  1,363,926   5.81%  183.068
# 6     7                  Rajasthan  1,413,620  1,218,193   5.19%  163.507
# 7     8             Madhya Pradesh  1,322,821  1,136,137   4.84%  152.494
# 8     9             Andhra Pradesh  1,317,728  1,133,837   4.83%  152.185
# 9    10                  Telangana  1,313,391  1,128,907   4.81%  151.523
# 10   11                     Kerala          -    932,470   3.97%  125.157
# 11   12                      Delhi  1,043,759    904,642   3.85%  121.422
# ...

# %%
driver = webdriver.Chrome()
driver.get('https://github.com/')

# %%
drop_down = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]')
action = webdriver.ActionChains(driver)
action.move_to_element(drop_down)
action.perform()
trending = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
trending.click()

# %%
reps_title = []
reps_desc = []
contri_count = []
lang_used = []
title = driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]/a')
desc = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
contri = driver.find_elements(By.XPATH,'//a[@class="Link Link--muted d-inline-block mr-3"]')
lang = driver.find_elements(By.XPATH,'//span[@itemprop="programmingLanguage"]')
for i in title:
    try:
        reps_title.append(i.text)
    except NoSuchElementException:
        reps_title.append(' - ')
for i in desc:
    try:
        reps_desc.append(i.text)
    except NoSuchElementException:
        reps_desc.append(' - ')
for i in contri:
    try:
        contri_count.append(i.text)
    except NoSuchElementException:
        contri_count.append(' - ')
for i in lang:
    try:
        lang_used.append(i.text)
    except NoSuchElementException:
        lang_used.append(' - ')
# Out:
# 50

# %%
contri_count1 = contri_count[0::2]
print(len(contri_count1))
print(len(reps_title),len(reps_desc),len(lang_used))
# Out:
# 25
# 25 21 19

# %%
reps_desc = []
desc = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in desc:
        reps_desc.append(i.text)
reps_desc
# Out:
# ['🕵️\u200d♂️ All-in-one OSINT tool for analysing any website',
#  'Nintendo Switch emulator',
#  'bpftop provides a dynamic real-time view of running eBPF programs. It displays the average runtime, events per second, and estimated total CPU % for each program.',
#  'Windows in a Docker container.',
#  'Automatic polyfill service.',
#  'A based rollup. 🥁',
#  'A framework for prompt tuning using Intent-based Prompt Calibration',
#  'A collective list of free APIs',
#  'SuperTux source code',
#  '👩🏿\u200d💻👨🏾\u200d💻👩🏼\u200d💻👨🏽\u200d💻👩🏻\u200d💻中国独立开发者项目列表 -- 分享大家都在做什么',
#  'There can be more than Notion and Miro. AFFiNE(pronounced [ə‘fain]) is a next-gen knowledge base that brings planning, sorting and creating all together. Privacy first, open-source, customizable and ready to use.',
#  'Animate Anyone: Consistent and Controllable Image-to-Video Synthesis for Character Animation',
#  'The distributed financial transactions database designed for mission critical safety and performance.',
# ...

# %%
reps_desc
# Out:
# ['🕵️\u200d♂️ All-in-one OSINT tool for analysing any website',
#  'Nintendo Switch emulator',
#  'bpftop provides a dynamic real-time view of running eBPF programs. It displays the average runtime, events per second, and estimated total CPU % for each program.',
#  'Windows in a Docker container.',
#  'Automatic polyfill service.',
#  'A based rollup. 🥁',
#  'A framework for prompt tuning using Intent-based Prompt Calibration',
#  'A collective list of free APIs',
#  'SuperTux source code',
#  '👩🏿\u200d💻👨🏾\u200d💻👩🏼\u200d💻👨🏽\u200d💻👩🏻\u200d💻中国独立开发者项目列表 -- 分享大家都在做什么',
#  'There can be more than Notion and Miro. AFFiNE(pronounced [ə‘fain]) is a next-gen knowledge base that brings planning, sorting and creating all together. Privacy first, open-source, customizable and ready to use.',
#  'Animate Anyone: Consistent and Controllable Image-to-Video Synthesis for Character Animation',
#  'The distributed financial transactions database designed for mission critical safety and performance.',
# ...

# %%
df = pd.DataFrame({'Repository Title':reps_title[:19],'Repository Description':reps_desc[:19],'Contributors Count':contri_count[:19],'Language':lang_used[:19]})
df
# Out:
#                        Repository Title  \
# 0                   Lissy93 / web-check
# 1                       yuzu-emu / yuzu
# 2                      Netflix / bpftop
# 3               yuzu-emu / yuzu-android
# 4                      dockur / windows
# 5   polyfillpolyfill / polyfill-service
# 6                 taikoxyz / taiko-mono
# 7                  Eladlev / AutoPrompt
# 8             public-apis / public-apis
# 9           Lunakepio / Mario-Kart-3.js
# 10                      HumanAIGC / EMO
# 11             yuzu-emu / yuzu-mainline
# 12                  SuperTux / supertux
# 13  1c7 / chinese-independent-developer
# 14                toeverything / AFFiNE
# 15            HumanAIGC / AnimateAnyone
# 16            tigerbeetle / tigerbeetle
# 17          pineappleEA / pineapple-src
# 18          pure-admin / vue-pure-admin
#
#                                Repository Description Contributors Count  \
# 0   🕵️‍♂️ All-in-one OSINT tool for analysing any ...             12,034
# ...

# %%
driver = webdriver.Chrome()
driver.get('https:/www.billboard.com/')

# %%
driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a').click()
time.sleep(2)
driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[1]/div/div[2]/span/a').click()

# %%
song_name = []
art_name=[]
lwr = []
pr = []
wob = []
song = driver.find_elements(By.XPATH,'//h3[@id="title-of-a-story"]')
artist = driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
last_r = driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]/span')
peak = driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]/span')
onboard = driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]/span')
for i in song:
    try:
        song_name.append(i.text)
    except NoSuchElementException:
        song_name.append(' - ')
for i in artist:
    try:
        art_name.append(i.text)
    except NoSuchElementException:
        art_name.append(' - ')
for i in last_r:
    try:
        lwr.append(i.text)
    except NoSuchElementException:
        lwr.append(' - ')
for i in peak:
    try:
        pr.append(i.text)
    except NoSuchElementException:
        pr.append(' - ')
for i in onboard:
    try:
        wob.append(i.text)
    except NoSuchElementException:
        wob.append(' - ')

# %%
song_name1 = song_name[6:406:4]
print(len(song_name1))
lwr1 = lwr[0::2]
print(len(lwr1))
wob1 = wob[1::2]
print(len(wob1))
# Out:
# 100
# 100
# 100

# %%
art_name
# Out:
# ['Jack Harlow',
#  'Teddy Swims',
#  '¥$: Kanye West & Ty Dolla $ign Featuring Rich The Kid & Playboi Carti',
#  'Benson Boone',
#  'SZA',
#  'Taylor Swift',
#  'Tate McRae',
#  'Zach Bryan Featuring Kacey Musgraves',
#  'Doja Cat',
#  'Ariana Grande',
#  'Noah Kahan',
#  'Luke Combs',
#  'Tyla',
#  'Morgan Wallen',
#  '21 Savage',
#  'Morgan Wallen',
#  'Taylor Swift',
#  'Warren Zeiders',
#  'Miley Cyrus',
#  'Doja Cat',
#  'Dua Lipa',
#  'Muni Long',
#  'Flo Milli',
#  'Xavi',
#  'Luke Combs',
#  'Dua Lipa',
#  'Cody Johnson',
#  'Sabrina Carpenter',
#  'Billie Eilish',
#  'Drake Featuring Sexyy Red & SZA',
#  'Bryson Tiller',
#  'HARDY',
#  'Justin Timberlake',
#  'Nicki Minaj Featuring Lil Uzi Vert',
#  'Olivia Rodrigo',
#  'Jessie Murph & Jelly Roll',
#  'Victoria Monet',
#  'YG Marley',
#  'Jelly Roll With Lainey Wilson',
#  'Tate McRae',
#  'Yeat',
#  'Dua Lipa',
#  'Jelly Roll',
#  'JID Featuring 21 Savage & Baby Tate',
#  'Nate Smith',
# ...

# %%
art_name.insert(0,'Beyonce')
print(len(art_name))
# Out:
# 100

# %%
df = pd.DataFrame({'Song Name':song_name1,'Artist name':art_name,'Last Week Rank':lwr1,'Peak Rank':pr,'Weeks On Chart':wob1})
df
# Out:
#             Song Name                                        Artist name  \
# 0      Texas Hold 'Em                                            Beyonce
# 1         Lovin On Me                                        Jack Harlow
# 2        Lose Control                                        Teddy Swims
# 3            Carnival  ¥$: Kanye West & Ty Dolla $ign Featuring Rich ...
# 4    Beautiful Things                                       Benson Boone
# ..                ...                                                ...
# 95            Talking  ¥$: Kanye West & Ty Dolla $ign Featuring North...
# 96             Monaco                                          Bad Bunny
# 97      Where It Ends                                   Bailey Zimmerman
# 98      Wondering Why                                The Red Clay Strays
# 99  Northern Attitude                             Noah Kahan With Hozier
#
#    Last Week Rank Peak Rank Weeks On Chart
# 0               2         1              2
# ...

# %%
driver = webdriver.Chrome()
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
info = []
data = driver.find_elements(By.TAG_NAME,'td')
for i in data:
    info.append(i.text)
info
# Out:
# ['SOURCE: NIELSEN BOOK SCAN',
#  '1',
#  'Da Vinci Code,The',
#  'Brown, Dan',
#  '5,094,805',
#  'Transworld',
#  'Crime, Thriller & Adventure',
#  '2',
#  'Harry Potter and the Deathly Hallows',
#  'Rowling, J.K.',
#  '4,475,152',
#  'Bloomsbury',
#  "Children's Fiction",
#  '3',
#  "Harry Potter and the Philosopher's Stone",
#  'Rowling, J.K.',
#  '4,200,654',
#  'Bloomsbury',
#  "Children's Fiction",
#  '4',
#  'Harry Potter and the Order of the Phoenix',
#  'Rowling, J.K.',
#  '4,179,479',
#  'Bloomsbury',
#  "Children's Fiction",
#  '5',
#  'Fifty Shades of Grey',
#  'James, E. L.',
#  '3,758,936',
#  'Random House',
#  'Romance & Sagas',
#  '6',
#  'Harry Potter and the Goblet of Fire',
#  'Rowling, J.K.',
#  '3,583,215',
#  'Bloomsbury',
#  "Children's Fiction",
#  '7',
#  'Harry Potter and the Chamber of Secrets',
#  'Rowling, J.K.',
#  '3,484,047',
#  'Bloomsbury',
#  "Children's Fiction",
#  '8',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Rowling, J.K.',
# ...

# %%
name = info[1::6]
author = info[2::6]
volumes = info[3::6]
publisher = info[4::6]
genre = info[5::6]

# %%
df = pd.DataFrame({'Title':name,'Author':author,'Volumes Sold':volumes,'Publisher':publisher,'Genre':genre})
df
# Out:
#    Title                                             Author      Volumes Sold  \
# 0      1                                  Da Vinci Code,The        Brown, Dan
# 1      2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2      3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3      4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4      5                               Fifty Shades of Grey      James, E. L.
# ..   ...                                                ...               ...
# 95    96                                          Ghost,The    Harris, Robert
# 96    97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97    98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98    99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99   100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#     Publisher            Genre
# ...

# %%
driver = webdriver.Chrome()
driver.get('https://www.imdb.com/list/ls512407256/')

# %%
name = []
year_span = []
genre = []
run = []
rate = []
vote = []
nam = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
year = driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span')
gen = driver.find_elements(By.XPATH,'//span[@class="genre"]')
runtm = driver.find_elements(By.XPATH,'//span[@class="runtime"]')
rat = driver.find_elements(By.XPATH,'//div[@class="ipl-rating-widget"]')
vot = driver.find_elements(By.XPATH,'//span[@name="nv"]')
for i in nam:
    name.append(i.text)
for i in year:
    year_span.append(i.text)
for i in gen:
    genre.append(i.text)
for i in runtm:
    run.append(i.text)
for i in rat:
    rate.append(i.text)
for i in vot:
    vote.append(i.text)

print(len(name),len(year_span),len(genre),len(run),len(rate),len(vote))
# Out:
# 100 200 100 100 100 100

# %%
year = year_span[1::2]
print(len(year))
# Out:
# 100

# %%
df = pd.DataFrame({'Name':name,'Year Span':year,'Genre':genre,'Rumtime':run,'Rating':rate,'Votes':vote})
df
# Out:
#                     Name    Year Span                     Genre Rumtime  \
# 0        Game of Thrones  (2011–2019)  Action, Adventure, Drama  55 min
# 1        Stranger Things  (2016–2025)    Drama, Fantasy, Horror  51 min
# 2       The Walking Dead  (2010–2022)   Drama, Horror, Thriller  44 min
# 3         13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller  60 min
# 4                The 100  (2014–2020)    Drama, Mystery, Sci-Fi  43 min
# ..                   ...          ...                       ...     ...
# 95        True Detective     (2014– )     Crime, Drama, Mystery  55 min
# 96             Teen Wolf  (2011–2017)    Action, Drama, Fantasy  41 min
# 97                The OA  (2016–2019)   Drama, Fantasy, Mystery  60 min
# 98          The Simpsons     (1989– )         Animation, Comedy  22 min
# 99  Desperate Housewives  (2004–2012)    Comedy, Drama, Mystery  45 min
#
#        Rating      Votes
# 0   9.2\nRate  2,262,002
# 1   8.7\nRate  1,320,102
# ...

# %%
driver = webdriver.Chrome()
driver.get('https://archive.ics.uci.edu/')

# %%
driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/header/nav/ul/li[1]/a').click()

# %%
driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[2]/div[1]/div/label[2]/div[2]/span[2]').click()

# %%
dname = []
data = []
task = []
att_typ = []
nins = []
natt = []
year = []

dn = driver.find_elements(By.XPATH,'//h2[@class="truncate text-primary"]/a')
dt = driver.find_elements(By.XPATH,'//span[@class="truncate"]')
tsk = driver.find_elements(By.XPATH,'//p[@class="truncate"]')
at_ty = driver.find_elements(By.TAG_NAME,'td')

for i in dn:
    dname.append(i.text)
for i in dt:
    data.append(i.text)
for i in tsk:
    task.append(i.text)
for i in at_ty:
    att_typ.append(i.text)
    
print(len(dname),len(data),len(task),len(att_typ))
# Out:
# 10 80 10 40

# %%
data_type = data[0::8]
print(data_type)
nins = data[2::8]
print(nins)
natt = data[3::8]
print(natt)
att_type = att_typ[1::4]
print(att_type)
year = att_typ[2::4]
print(year)
# Out:
# ['Classification', 'Classification', 'Classification', 'Classification', 'Classification', 'Classification', 'Classification', 'Classification', 'Classification, Regression', 'Classification']
# ['150 Instances', '13.61K Instances', '303 Instances', '3.81K Instances', '48.84K Instances', '900 Instances', '569 Instances', '178 Instances', '4.9K Instances', '1 Instances']
# ['4 Features', '16 Features', '13 Features', '7 Features', '14 Features', '8 Features', '30 Features', '13 Features', '12 Features', '20 Features']
# ['Real', 'Integer, Real', 'Categorical, Integer, Real', 'Real', 'Categorical, Integer', 'Real, Integer', 'Real', 'Integer, Real', 'Real', 'Categorical, Integer']
# ['7/1/1988', '9/14/2020', '7/1/1988', '10/6/2019', '5/1/1996', '8/14/2023', '11/1/1995', '7/1/1991', '10/7/2009', 'N/A']

# %%
df = pd.DataFrame({'Dataset Name':dname,'Data Type':data_type,'Task':task,'Attribute type':att_type,'No. of instances':nins,'No.of attributes':natt,'Year':year})
df
# Out:
#                            Dataset Name                   Data Type  \
# 0                                  Iris              Classification
# 1                      Dry Bean Dataset              Classification
# 2                         Heart Disease              Classification
# 3            Rice (Cammeo and Osmancik)              Classification
# 4                                 Adult              Classification
# 5                                Raisin              Classification
# 6  Breast Cancer Wisconsin (Diagnostic)              Classification
# 7                                  Wine              Classification
# 8                          Wine Quality  Classification, Regression
# 9                              Diabetes              Classification
#
#                                                 Task  \
# 0  A small classic dataset from Fisher, 1936. One...
# 1  Images of 13,611 grains of 7 different registe...
# 2  4 databases: Cleveland, Hungary, Switzerland, ...
# ...
